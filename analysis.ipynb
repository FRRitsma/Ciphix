# %% [markdown]
# ## Analysis, Step by Step

# %%
# Modules:
import pandas as pd
import numpy as np
# Load data:
if 'df_main' not in globals().keys():    
    # Main function of cell is to display data, if statements prevents re-load:
    df_main = pd.read_csv('data.csv', header=None)
    df_main.columns = ['text']

# Form of data:
print(f"Shape of data: {df_main.shape}")

# Data has missing values:
print(f"Data has nans: {df_main.isnull().values.any()}")

# Display random rows:
idx = np.random.randint(len(df_main))
df_main[idx:].head()
# Out:
# Shape of data: (2811774, 1)
# Data has nans: False
#                                                      text
# 501467  @252761 Hey there! Sorry about that. We’d reco...
# 501468  @SpotifyCares @159550 Can you help us? our EP ...
# 501469  @252762 Hey Peter! Can you DM us the link so w...
# 501470              @SpotifyCares https://t.co/ZLrT5waWaC
# 501471  @252762 Thanks, we'll get this reported. If yo...

# %% [markdown]
# #### First Impressions
#
# The data consists in a collection of tweets, mostly customer support, sent by users or companies in a dialogue form. The data is remarkably unstructured. A possibly useful feature is that tweets can be clearly directed at the company via "@company" or to an anonimized user via "@12345". This seems to be the most useful type of information contained in the data so far, although if a help request addresses a specific employee it is also anonimized.

# %%
from process_tags import *

print("--Can a tweet be directed at both a user and a company?")
for i in df_main['text']:
    if has_user_name(i) and has_company_name(i):
        print('yes ->' + i)
        break

print("--Can a tweet be directed at multiple companies?")
for i in df_main['text']:
    if count_company_names(i) > 1:
        print('yes ->' + i)
        break

print("--Can a tweet be directed at multiple users?")
for i in df_main['text']:
    if count_user_names(i) > 1:
        print('yes ->' + i)
        break
# Out:
# --Can a tweet be directed at both a user and a company?
# yes ->@ChipotleTweets @28
# I don't fit in my Veggie Burrito costume #Halloween https://t.co/7tJDVpzLWn
# --Can a tweet be directed at multiple companies?
# yes ->@MicrosoftHelps @XboxSupport Brilliant, thank you!
# --Can a tweet be directed at multiple users?
# yes ->.@VerizonSupport @115725 @115726                                                 &gt;All of VERIZON IS DOWN&lt;
# When can we expect a fix ?

# %% [markdown]
# #### Format of Data
# Intermediate conclusions are somewhat pessimistic. There seems to be no fool proof and easy way to make out whether a tweet is coming from a user or a company. An additional difficulty is that some tweets form part of conversation, and there is additionally no easy way to determine which tweet has initialized the conversation or when the conversation has ended.
#
# #### Types of Tweets
# Mostly help requests, though some tweets are just randomly sent out to show support for a company.
#
# #### Intermediate conclusion
# The best way to continue the data analysis would be to employ unsupervised learning to hope for more easily processed insights.
#
# ## The Bigger Picture - How can value be extracted?
# Now that we have somewhat of an idea of the type of data we are dealing with, the question becomes "How can value be extracted". I think the most usefull things for a company to know are:
# 1. When have I received a request for support?
# 2. When has the customer support been completed?
# 3. Can these things be derived from the contents of a tweet?

# %% [markdown]
# #### Topic Discovery
# The assignment asks for us to discover 10 topics. In my view the next logical approach is to use unsupservised learning.

# %%
from textprocessing import *
import os
import pickle
jn      = os.path.join
is_f    = os.path.isfile

# Create folder structure - if it does not exist:
prepare_setup()

# Prepare data - or load:
path = jn('artifacts','data','df_unsupervised.pkl')
if not os.path.isfile(path):
    df_unsupervised = df_main.sample(frac = .01)
    df_unsupervised['text'] = df_unsupervised['text'].apply(process_sentence)
    df_unsupervised.to_pickle(path)
else:
    df_unsupervised = pd.read_pickle(path)

# Create latent dirichlet model - or load:
if is_f(jn('artifacts', 'models', 'lda.pkl')) and is_f(jn('artifacts', 'models', 'countvec.pkl')):
    # Load:
    with open(jn('artifacts', 'models', 'countvec.pkl'), 'rb') as fs:
        countvec = pickle.load(fs)
    with open(jn('artifacts', 'models', 'lda.pkl'), 'rb') as fs:
        lda = pickle.load(fs)
else:
    countvec, lda = train_lda_model(df_unsupervised['text'])
    # Save:
    with open(jn('artifacts', 'models', 'lda.pkl'), 'wb') as fs:
        pickle.dump(countvec, fs)
    with open(jn('artifacts', 'models', 'countvec.pkl'), 'wb') as fs:
        pickle.dump(countvec, fs)
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/vscode/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /home/vscode/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /home/vscode/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /home/vscode/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to /home/vscode/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /home/vscode/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /home/vscode/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /home/vscode/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to /home/vscode/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /home/vscode/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /home/vscode/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /home/vscode/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
import matplotlib.pyplot as plt

#lda.transform(countvec.transform(process_sentence(["Hello let's go"])))
#lda.transform(countvec.transform([process_sentence("delayed flight")]))
# 
components = lda.components_
words = countvec.get_feature_names_out()
for i in range(1):
    component = components[i,:]
    top_words = words[np.argsort(-component)]



#countvec.get_feature_names_out()

# %%
top_words
# Out:
# array(['issue', 'like', 'thanks', 'would', 'try', 'feedback', 'us', 'day',
#        'device', 'share', 'always', 'update', 'resolved', 'problem',
#        'hope', 'better', 'experience', 'review', 'resolve', 'got', 'know',
#        'able', 'network', 'end', 'appreciate', 'reply', 'latest', 'kind',
#        'moment', 'goes', 'see', 'please', 'great', 'sort', 'additional',
#        'make', 'assist', 'sure', 'provide', 'want', 'location',
#        'response', 'article', 'kindly', 'console', 'trip', 'love',
#        'power', 'record', 'understand', 'looking', 'version', 'start',
#        'leave', 'system', 'reaching', 'improve', 'next', 'attention',
#        'glad', 'new', 'different', 'browser', 'affected', 'something',
#        'use', 'link', 'apologize', 'evening', 'mac', 'aware', 'help',
#        'read', 'log', 'forward', 'run', 'button', 'slow', 'recent',
#        'locator', 'test', 'section', 'good', 'situation', 'dont',
#        'either', 'concern', 'chance', 'concerning', 'morning',
#        'following', 'soon', 'rest', 'related', 'area', 'brand', 'hell',
#        'find', 'cache', 'accept', 'word', 'known', 'suggest', 'shut',
#        'right', 'elaborate', 'operating', 'appear', 'ways', 'weird',
#        'dan', 'never', 'david', 'rather', 'accordingly', 'give', 'tweet',
#        'may', 'ur', 'server', 'coverage', 'part', 'important', 'sorted',
#        'within', 'running', 'printer', 'lot', 'reinstall', 'still',
#        'taking', 'clear', 'speed', 'idea', 'restart', 'weather', 'logged',
#        'internally', 'due', 'checked', 'family', 'saw', 'later',
#        'loading', 'notice', 'appropriate', 'post', 'travel', 'matter',
#        'treat', 'getting', 'wrong', 'attempt', 'confirming', 'someone',
#        'option', 'lose', 'used', 'learn', 'bit', 'sorry', 'tag',
#        'current', 'router', 'every', 'michael', 'single', 'inconvenience',
#        'error', 'safe', 'recommend', 'thing', 'get', 'fast', 'anyone',
#        'baggage', 'outside', 'one', 'unacceptable', 'little', 'provided',
#        'exact', 'choosing', 'follow', 'causing', 'advise', 'usually',
#        'mail', 'shopping', 'process', 'trouble', 'natalie', 'talk',
#        'lovely', 'starting', 'charge', 'explain', 'specific', 'ah',
#        'quickly', 'literally', 'instead', 'search', 'click', 'chris',
#        'disappointment', 'another', 'certain', 'seem', 'wish', 'priority',
#        'road', 'fare', 'middle', 'high', 'move', 'mobile', 'posted',
#        'continue', 'pop', 'action', 'experienced', 'center', 'load',
#        'afraid', 'worked', 'sense', 'valid', 'deliver', 'properly',
#        'home', 'almost', 'way', 'plan', 'assistance', 'manager', 'yes',
#        'particular', 'true', 'release', 'two', 'enough', 'min', 'song',
#        'ask', 'size', 'sam', 'sound', 'frustration', 'jordan', 'tom',
#        'simple', 'confusion', 'time', 'special', 'patience', 'normal',
#        'mind', 'twitter', 'go', 'step', 'let', 'put', 'given', 'business',
#        'air', 'least', 'actually', 'best', 'leaving', 'today', 'wo',
#        'paul', 'cost', 'else', 'verify', 'avoid', 'take', 'work', 'lack',
#        'trying', 'report', 'as', 'order', 'yesterday', 'open',
#        'promotion', 'hey', 'people', 'late', 'meet', 'team', 'far',
#        'store', 'side', 'choose', 'charging', 'could', 'received',
#        'working', 'file', 'think', 'booking', 'everything', 'service',
#        'giving', 'happy', 'stop', 'regarding', 'pick', 'speak',
#        'previous', 'went', 'flying', 'stuck', 'half', 'sending', 'screen',
#        'data', 'look', 'claim', 'send', 'maintenance', 'flight', 'xmas',
#        'via', 'quite', 'watch', 'for', 'reservation', 'since', 'missing',
#        'hear', 'back', 'wait', 'phil', 'journey', 'detail', 'ensure',
#        'previously', 'bring', 'understanding', 'also', 'web', 'matt',
#        'well', 'possible', 'helping', 'ahead', 'bought', 'write', 'might',
#        'making', 'chicken', 'john', 'hotel', 'assured', 'point', 'prior',
#        'together', 'clarify', 'odd', 'however', 'quick', 'future',
#        'exactly', 'listening', 'constantly', 'change', 'resolution',
#        'beyond', 'demand', 'warranty', 'discuss', 'correct', 'taken',
#        'luck', 'create', 'access', 'everyone', 'horrible', 'drop', 'add',
#        'department', 'away', 'zip', 'show', 'steven', 'handle', 'hearing',
#        'model', 'along', 'oh', 'really', 'facing', 'happening', 'request',
#        'difference', 'direct', 'unable', 'freezing', 'seeing', 'eligible',
#        'availability', 'difficult', 'certainly', 'site', 'check',
#        'whenever', 'connected', 'happen', 'prompt', 'decided', 'install',
#        'piece', 'bottom', 'interest', 'connection', 'fault', 'gave',
#        'media', 'machine', 'truly', 'tried', 'logging', 'information',
#        'friend', 'refer', 'randomly', 'user', 'definitely', 'the',
#        'guess', 'keep', 'subscription', 'type', 'id', 'reset', 'much',
#        'taste', 'many', 'usual', 'submit', 'yet', 'nice', 'luggage',
#        'currently', 'recently', 'receive', 'spoke', 'computer', 'cable',
#        'near', 'already', 'bug', 'fix', 'select', 'guide', 'turning',
#        'sad', 'fun', 'lewis', 'upset', 'solution', 'waste', 'discount',
#        'deal', 'page', 'video', 'delay', 'expect', 'item', 'must',
#        'concerned', 'remove', 'box', 'value', 'showing', 'code',
#        'immediately', 'providing', 'region', 'course', 'program',
#        'listed', 'attached', 'board', 'include', 'message', 'consider',
#        'original', 'investigate', 'apparently', 'calling', 'billing',
#        'platform', 'switch', 'longer', 'seriously', 'afternoon', 'mine',
#        'query', 'real', 'allow', 'wondering', 'tell', 'ring', 'plus',
#        'refund', 'job', 'made', 'couple', 'unless', 'confirm', 'stay',
#        'going', 'call', 'book', 'sell', 'thought', 'login', 'replace',
#        'extremely', 'fine', 'regret', 'nothing', 'man', 'often', 'care',
#        'bad', 'poor', 'cause', 'place', 'complete', 'worry', 'hot',
#        'locate', 'ca', 'content', 'worth', 'stuff', 'live', 'relevant',
#        'mark', 'outage', 'customer', 'welcome', 'tuned', 'space', 'buy',
#        'party', 'mike', 'awesome', 'enjoy', 'pass', 'long', 'wife',
#        'visit', 'profile', 'reach', 'super', 'lost', 'phone', 'without',
#        'tech', 'product', 'saying', 'catch', 'advance', 'shout', 'pay',
#        'price', 'son', 'hand', 'apply', 'return', 'last', 'social',
#        'repair', 'wonderful', 'miss', 'public', 'wireless', 'left',
#        'case', 'turn', 'even', 'come', 'shop', 'need', 'hard', 'broken',
#        'channel', 'busy', 'helpful', 'josh', 'sometimes', 'preferred',
#        'standing', 'no', 'amazing', 'terrible', 'chat', 'drive',
#        'telling', 'music', 'stream', 'bonus', 'dial', 'india', 'loyalty',
#        'signal', 'branch', 'office', 'coming', 'delete', 'offer', 'city',
#        'clearly', 'station', 'finally', 'mean', 'feel', 'package',
#        'closed', 'disconnected', 'second', 'works', 'battery', 'first',
#        'company', 'replacement', 'match', 'save', 'stupid', 'opening',
#        'needs', 'done', 'view', 'black', 'house', 'fully', 'though',
#        'will', 'news', 'completely', 'straight', 'life', 'associated',
#        'told', 'country', 'account', 'world', 'front', 'figure', 'year',
#        'date', 'directly', 'rude', 'carrier', 'season', 'guy', 'shall',
#        'quality', 'ass', 'member', 'based', 'keyboard', 'feature',
#        'upgrade', 'turned', 'top', 'track', 'none', 'believe', 'added',
#        'support', 'train', 'hold', 'copy', 'weekend', 'losing', 'advised',
#        'confirmed', 'across', 'confirmation', 'state', 'available',
#        'disappointing', 'free', 'shortly', 'brought', 'monday',
#        'reference', 'hour', 'carry', 'pretty', 'comes', 'number', 'set',
#        'fly', 'transaction', 'money', 'per', 'ended', 'daily', 'ago',
#        'hate', 'ever', 'fact', 'cool', 'tho', 'hello', 'james', 'ok',
#        'said', 'disruption', 'staff', 'hesitate', 'local', 'damn',
#        'student', 'unfortunately', 'balance', 'agent', 'join', 'say',
#        'whole', 'purchase', 'came', 'route', 'name', 'picture', 'die',
#        'month', 'tonight', 'joke', 'whether', 'old', 'times', 'sign',
#        'maybe', 'kept', 'found', 'active', 'thank', 'days', 'meal',
#        'kevin', 'password', 'ticket', 'door', 'connect', 'disappointed',
#        'hit', 'big', 'person', 'form', 'tomorrow', 'anywhere', 'fee',
#        'took', 'delivery', 'informed', 'entire', 'food', 'ridiculous',
#        'boarding', 'stopped', 'list', 'management', 'supplier',
#        'automatically', 'line', 'volume', 'correspondence', 'english',
#        'rep', 'reason', 'dear', 'partner', 'anyway', 'moving', 'spoken',
#        'three', 'destination', 'complaint', 'bag', 'non', 'cut', 'extra',
#        'respond', 'elsewhere', 'less', 'photo', 'row', 'unlimited',
#        'status', 'contact', 'amazon', 'hi', 'fill', 'monthly', 'control',
#        'statement', 'listen', 'contract', 'sandwich', 'shipped', 'ad',
#        'picked', 'receipt', 'total', 'answer', 'meant', 'touch', 'cheese',
#        'excited', 'useless', 'transfer', 'seen', 'onto', 'car',
#        'departure', 'cancel', 'street', 'full', 'week', 'night',
#        'thursday', 'spend', 'airport', 'game', 'sick', 'fixed', 'cash',
#        'schedule', 'several', 'selling', 'alex', 'ta', 'digital',
#        'friday', 'saturday', 'policy', 'plastic', 'pending', 'streaming',
#        'pack', 'switching', 'safety', 'spent', 'twice', 'supposed',
#        'anything', 'multiple', 'private', 'driver', 'stock', 'worse',
#        'play', 'watching', 'mistake', 'gate', 'language', 'closer',
#        'waiting', 'blocked', 'address', 'arrive', 'paying', 'ordered',
#        'sent', 'early', 'courier', 'past', 'apple', 'letter', 'advice',
#        'crew', 'card', 'personal', 'awful', 'probably', 'window',
#        'acceptable', 'double', 'around', 'seat', 'delta', 'payment',
#        'security', 'sold', 'nearest', 'enter', 'don', 'credit', 'totally',
#        'bill', 'cant', 'feed', 'wan', 'amount', 'despite', 'note',
#        'minute', 'annoying', 'registered', 'ready', 'linked', 'class',
#        'collect', 'booked', 'pathetic', 'cold', 'october', 'arrival',
#        'november', 'trash', 'empty', 'prime', 'birthday', 'crap',
#        'membership', 'compensation', 'na', 'gift', 'plane', 'ruined',
#        'close', 'worst', 'fail', 'ride', 'room', 'seller', 'parcel',
#        'american', 'notification', 'burrito', 'question', 'removed',
#        'sitting', 'voucher', 'tired', 'shipping', 'sunday', 'fraud',
#        'sale', 'ship', 'text', 'attendant', 'red', 'till', 'christmas',
#        'communication', 'cancellation', 'eye', 'suck', 'fan', 'gone',
#        'gon', 'head', 'premium', 'mi', 'pic', 'album', 'inside', 'ya',
#        'absolutely', 'returned', 'se', 'breakfast', 'sit', 'bank', 'girl',
#        'pour', 'visible', 'driving', 'si', 'pizza', 'ich', 'halloween',
#        'un', 'en', 'la', 'el', 'de', 'prefer', 'ist', 'ne', 'das', 'es',
#        'backstage', 'para', 'te', 'ha', 'tu', 'al', 'lo', 'con'],
#       dtype=object)
